# %%
from variables import *
from wp4_1 import Aerodynamics, InternalForces
from wp4_2 import WingBox

xflr_files = 'XFLRdata\\XFLR5sims'

# change these
aircraft_mass = 35688
alt_sound_speed = 296.56

internal_forces = InternalForces(aircraft_mass=aircraft_mass, load_factor= load_factor, sound_speed=alt_sound_speed, half_chord_sweep= hchord_sweep, fus_radius=fus_radius, density=rho0, airspeed= airspeed, 
                                 c_r= c_r, wingspan= b, engine_z_loc= engine_z_loc, engine_length= engine_length, x_hl= x_hl, x_lemac= x_lemac, MAC= MAC, 
                                 one_engine_thrust= one_engine_thrust, fan_cowl_diameter= fan_cowl_diameter, c_t= c_r*tr)
    
    
g_shear, g_moment, g_torque, g_axial = internal_forces.force_diagrams(engine_mass=engine_mass, wing_box_length=wing_box_length, 
                                        fuel_tank_length=fuel_tank_length, fuel_density=fuel_density)[4:]
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[11], line 11
#       8 aircraft_mass = 35688
#       9 alt_sound_speed = 296.56
# ---> 11 internal_forces = InternalForces(aircraft_mass=aircraft_mass, load_factor= load_factor, sound_speed=alt_sound_speed, half_chord_sweep= hchord_sweep, fus_radius=fus_radius, density=rho0, airspeed= airspeed,
#      12                                  c_r= c_r, wingspan= b, engine_z_loc= engine_z_loc, engine_length= engine_length, x_hl= x_hl, x_lemac= x_lemac, MAC= MAC,
#      13                                  one_engine_thrust= one_engine_thrust, fan_cowl_diameter= fan_cowl_diameter, c_t= c_r*tr)
#      16 g_shear, g_moment, g_torque, g_axial = internal_forces.force_diagrams(engine_mass=engine_mass, wing_box_length=wing_box_length,
#      17                                         fuel_tank_length=fuel_tank_length, fuel_density=fuel_density)[4:]
#
# File c:\Users\feder\Documents\Personal\education\TU Delft\Bsc2\Q1\AE2111-I\WP4-5\wp4_1.py:107, in InternalForces.__init__(self, aircraft_mass, load_factor, sound_speed, half_chord_sweep, fus_radius, density, airspeed, c_r, wingspan, engine_z_loc, engine_length, x_hl, x_lemac, MAC, one_engine_thrust, fan_cowl_diameter, c_t)
#     101 self.aircraft_mass = aircraft_mass
#     103 # self.g_cl = distributions[0]
#     104 # self.g_cd = distributions[1]
#     105 # self.g_cm = distributions[2]
# --> 107 self.lift_dist, self.torque_dist, self.drag_dist = self.applied_distributions()
#
# File c:\Users\feder\Documents\Personal\education\TU Delft\Bsc2\Q1\AE2111-I\WP4-5\wp4_1.py:191, in InternalForces.applied_distributions(self)
#     189 N_z = []
#     190 for i in self.z_points:
# --> 191     L_z.append(self.calculate_CL_0_and_10()[0](i) * self.q * chord_dist_z.subs(z, i) / np.sqrt(1-(self.airspeed/self.sound_speed)**2))
#     192     T_z.append(self.calculate_CL_0_and_10()[1](i) * self.q * chord_dist_z.subs(z, i) / np.sqrt(1-(self.airspeed/self.sound_speed)**2) / np.sqrt(1-(self.airspeed/self.sound_speed)**2))
#     193     D_z.append(self.calculate_CL_0_and_10()[2](i) * self.q * chord_dist_z.subs(z, i) / np.sqrt(1-(self.airspeed/self.sound_speed)**2) / np.sqrt(1-(self.airspeed/self.sound_speed)**2))
#
# File c:\Users\feder\Documents\Personal\education\TU Delft\Bsc2\Q1\AE2111-I\WP4-5\wp4_1.py:140, in InternalForces.calculate_CL_0_and_10(self)
#     134 def calculate_CL_0_and_10(self):
#     135
#     136     # Create Aerodynamics instances for 0° and 10° AoA
#     137     aerodynamics_0 = Aerodynamics(
#     138         folder="XFLRdata\\XFLR5sims",
#     139         aoa=0, wingspan=self.ogwingspan, fus_radius=self.fus_radius)
# --> 140     g_cl0, g_cd0, g_cm0 = aerodynamics_0.coefficients(return_list=False)
#     142     aerodynamics_10 = Aerodynamics(
#     143         folder="XFLRdata\\XFLR5sims",
#     144         aoa=10, wingspan=self.ogwingspan, fus_radius=self.fus_radius)
#     145     g_cl10, g_cd10, g_cm10 = aerodynamics_10.coefficients(return_list=False)
#
# File c:\Users\feder\Documents\Personal\education\TU Delft\Bsc2\Q1\AE2111-I\WP4-5\wp4_1.py:21, in Aerodynamics.coefficients(self, return_list)
#      19 def coefficients(self, return_list: bool):
#      20     #print(self.files[self.aoa])
# ---> 21     ylst = np.genfromtxt(self.files[self.aoa], skip_header=40, max_rows=19, usecols=(0,), invalid_raise=False)
#      22     Cllst = np.genfromtxt(self.files[self.aoa], skip_header=40, max_rows=19, usecols=(3,), invalid_raise=False)
#      23     Cdlst = np.genfromtxt(self.files[self.aoa], skip_header=40, max_rows=19, usecols=(5,), invalid_raise=False)
#
# File c:\Users\feder\anaconda3\Lib\site-packages\numpy\lib\npyio.py:2003, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    2001 try:
#    2002     for i in range(skip_header):
# -> 2003         next(fhd)
#    2005     # Keep on until we find the first valid values
#    2006     first_values = None
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb0 in position 129: invalid start byte
